# %% [markdown]
# #Instalando my sql

# %%
# !pip install mysql-connector-python

# %% [markdown]
# #Import do pandas e sql

# %%
import pandas as pd
import mysql.connector

# %% [markdown]
# #Conexão

# %%
user = 'root'
password = ''
database = 'locadora'
host = '34.44.38.90'

# %% [markdown]
# #Verificando IP

# %%
# !curl ipecho.net/plain
# Out:
# 35.197.125.120

# %% [markdown]
# #Conexão

# %%
def consulta(query, tabela):
  connection = mysql.connector.connect(
      host = host,
      user = user,
      password = password,
      database = database
  )
  cursor = connection.cursor()

  try:
    cursor.execute(query)
    result = cursor.fetchall()
    globals()[tabela] = pd.DataFrame(result, columns=cursor.column_names)
    display(globals()[tabela])
  finally:
    cursor.close()
    connection.close()

# %% [markdown]
# #Todas as tabelas

# %%
consulta('''
show tables;
''','tabelas')
# Out:
#   Tables_in_locadora
# 0            aluguel
# 1              carro
# 2            cliente
# 3              marca

# %% [markdown]
# ##Tabela aluguel

# %%
consulta('''
SELECT *
FROM aluguel;
''','alugueis')
# Out:
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25

# %% [markdown]
# ##Tabela clientes

# %%
consulta('''
SELECT *
FROM cliente;
''','clientes')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %% [markdown]
# ##Tabela carros

# %%
consulta('''
SELECT *
FROM carro;
''','carros')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0

# %% [markdown]
# ##Tabela marcas

# %%
consulta('''
SELECT *
FROM marca;
''','marcas')
# Out:
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

# %% [markdown]
# #Exercícios
# ---

# %% [markdown]
# #1- Selecione todos os dados da tabela cliente

# %%
consulta('''
SELECT *
FROM cliente;
''','nomes_clientes')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %% [markdown]
# #2 - Liste todos os clientes que moram na cidade de "São Paulo".

# %%
consulta('''
SELECT * FROM cliente
WHERE cidade = 'São Paulo';
''','clientes_SP')
# Out:
#    codcliente           nome     cidade sexo estado estadocivil
# 0           5  Lúcia Andrade  São Paulo    F     SP           C

# %% [markdown]
# #3 - Liste os estados diferentes presentes na tabela cliente.

# %%
consulta('''
SELECT DISTINCT estado
FROM cliente;
''','ufs')
# Out:
#   estado
# 0     RJ
# 1     SP

# %% [markdown]
# #4 - Liste todos os clientes ordenados pelo nome em ordem alfabética.

# %%
consulta('''
SELECT nome
FROM cliente
ORDER BY nome;
''','nomes_clientes')
# Out:
#                nome
# 0         Ana Silva
# 1     Bruna Pereira
# 2    Fernando Souza
# 3     Lúcia Andrade
# 4  Túlio Nascimento

# %% [markdown]
# # 5- Encontre todos os clientes que são do sexo feminino e solteiros.

# %%
consulta('''
SELECT nome
FROM cliente
WHERE sexo ='feminino' and estadocivil ='S'
''','estadocivil_clientes')
# Out:
# Empty DataFrame
# Columns: [nome]
# Index: []

# %% [markdown]
# # 6 - Liste todos os clientes cujo nome começa com a letra 'A'.

# %%
consulta('''
SELECT nome
FROM cliente
WHERE BINARY nome LIKE 'A%';
''','nomes_comA')
# Out:
#         nome
# 0  Ana Silva

# %% [markdown]
# #7 - Selecione os 3 primeiros registros da tabela cliente.

# %%
consulta('''
SELECT *
FROM cliente
LIMIT 3;
''','Top3')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %% [markdown]
# # 8 - Liste todos os carros que são da marca 'Ford' ou 'Fiat'.

# %%
consulta('''
SELECT c.modelo, m.marca
FROM carro AS c
INNER JOIN marca AS m
ON c.codmarca = m.codmarca
WHERE marca ='Fiat' OR marca ='Ford';
''','''inner_join''')
# Out:
#   modelo marca
# 0     Ka  Ford
# 1   Argo  Fiat

# %% [markdown]
# # 9 - Encontre todos os carros cujo valor está entre 100 e 150.

# %%
consulta('''
SELECT *
FROM carro
WHERE valor BETWEEN 100 AND 150;
''','''valores''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         4         4   Polo  150.0
# 3         5         5   Kwid  120.0

# %% [markdown]
# # 10 - Conte quantos aluguéis foram realizados.

# %%
consulta('''
SELECT COUNT(data_aluguel) AS total_alugueis
FROM aluguel;
''', 'contagem_aluguel')
# Out:
#    total_alugueis
# 0              10

# %% [markdown]
# # 11 - Calcule o valor total de todos os carros disponíveis para aluguel.

# %%
consulta('''
SELECT SUM(valor) AS 'valor_total'
FROM carro;
''', 'soma_aluguel')
# Out:
#    valor_total
# 0        690.0

# %% [markdown]
# # 12 - Calcule o valor médio dos carros.

# %%
consulta('''
SELECT AVG(valor) AS total_medio
FROM carro;
''', 'total_medio')
# Out:
#    total_medio
# 0        138.0

# %% [markdown]
# # 13 - Encontre o menor e o maior valor de aluguel de carros.

# %%
consulta('''
SELECT MAX(valor) AS max_carro
FROM carro;
''', 'maior_valor')


consulta('''
SELECT MIN(valor) AS min_carro
FROM carro;
''', 'menor_valor')
# Out:
#    max_carro
# 0      170.0
#    min_carro
# 0      100.0

# %% [markdown]
# # 14 - Agrupe os clientes por estado e conte quantos clientes existem em cada estado.

# %%
consulta('''
SELECT estado, COUNT(codcliente) AS 'clientes por estado'
FROM cliente
GROUP BY estado;
''','cliente_estado')
# Out:
#   estado  clientes por estado
# 0     RJ                    3
# 1     SP                    2

# %% [markdown]
# # 15 - Agrupe os aluguéis por cliente e filtre apenas aqueles que fizeram mais de 2 aluguéis.

# %%
consulta('''
SELECT codcliente as 'Id cliente', COUNT(*) as 'Qtd. de contratos'
FROM aluguel
GROUP BY codcliente
HAVING COUNT(codaluguel) > 2;
''','cliente_estado')
# Out:
#    Id cliente  Qtd. de contratos
# 0           1                  3
# 1           2                  3

# %% [markdown]
# # 16 - Liste todos os aluguéis, mostrando o nome do cliente e o modelo do carro alugado.

# %%
consulta('''
SELECT cl.nome, ca.modelo as 'modelo alugado'
FROM cliente AS cl
JOIN aluguel AS al
 ON cl.codcliente = al.codcliente
 JOIN carro AS ca
 ON al.codcarro = ca.codcarro;

''','''complexo''')
# Out:
#                nome modelo alugado
# 0  Túlio Nascimento           Argo
# 1     Bruna Pereira             Ka
# 2     Bruna Pereira             Ka
# 3     Bruna Pereira           Onix
# 4         Ana Silva           Polo
# 5         Ana Silva           Polo
# 6         Ana Silva             Ka
# 7     Lúcia Andrade           Argo
# 8     Lúcia Andrade           Argo
# 9  Túlio Nascimento             Ka

# %% [markdown]
# #17 - Liste todos os carros e, se houver, as informações sobre os aluguéis realizados desses carros.

# %%
consulta('''
SELECT ca.modelo,  al.data_aluguel
FROM carro AS ca
LEFT JOIN aluguel AS al ON ca.codcarro = al.codcarro;

''','''complexo''')
# Out:
#    modelo data_aluguel
# 0      Ka   2023-04-02
# 1      Ka   2023-04-03
# 2      Ka   2023-04-15
# 3      Ka   2023-04-25
# 4    Argo   2023-04-01
# 5    Argo   2023-04-19
# 6    Argo   2023-04-21
# 7    Onix   2023-04-04
# 8    Polo   2023-04-05
# 9    Polo   2023-04-13
# 10   Kwid         None

# %% [markdown]
# #18 - Liste todos os aluguéis e as informações sobre os carros alugados, mesmo que o carro não esteja mais no banco de dados.

# %%
consulta('''
SELECT ca.modelo,  al.data_aluguel
FROM carro AS ca
LEFT JOIN aluguel AS al ON ca.codcarro = al.codcarro;

''','''complexo''')
# Out:
#    modelo data_aluguel
# 0      Ka   2023-04-02
# 1      Ka   2023-04-03
# 2      Ka   2023-04-15
# 3      Ka   2023-04-25
# 4    Argo   2023-04-01
# 5    Argo   2023-04-19
# 6    Argo   2023-04-21
# 7    Onix   2023-04-04
# 8    Polo   2023-04-05
# 9    Polo   2023-04-13
# 10   Kwid         None

# %% [markdown]
# #19 - Liste todos os clientes e os carros que alugaram, incluindo clientes que não alugaram e carros que não foram alugados.

# %%
consulta('''
SELECT cl.nome AS cliente, ca.modelo AS carro
FROM cliente AS cl
LEFT JOIN aluguel AS al ON cl.codcliente = al.codcliente
LEFT JOIN carro AS ca ON al.codcarro = ca.codcarro

UNION

SELECT cl.nome AS cliente, ca.modelo AS carro
FROM carro AS ca
RIGHT JOIN aluguel AS al ON ca.codcarro = al.codcarro
RIGHT JOIN cliente AS cl ON al.codcliente = cl.codcliente;
''', 'resultado_unificado')
# Out:
#             cliente carro
# 0         Ana Silva  Polo
# 1         Ana Silva    Ka
# 2     Bruna Pereira    Ka
# 3     Bruna Pereira  Onix
# 4  Túlio Nascimento  Argo
# 5  Túlio Nascimento    Ka
# 6    Fernando Souza  None
# 7     Lúcia Andrade  Argo
# 8              None  Kwid

# %% [markdown]
# #20 - Combine os resultados de duas consultas: uma que lista clientes solteiros e outra que lista clientes casados.

# %%
consulta('''
SELECT nome, estadocivil
FROM cliente
WHERE estadocivil ='S'
 UNION
SELECT nome, estadocivil
FROM cliente
WHERE estadocivil ="C"
''','Estado_civil')
# Out:
#                nome estadocivil
# 0  Túlio Nascimento           S
# 1    Fernando Souza           S
# 2         Ana Silva           C
# 3     Bruna Pereira           C
# 4     Lúcia Andrade           C

# %% [markdown]
# #21 - Encontre os clientes que alugaram o carro com modelo 'Onix'.

# %%
consulta('''

SELECT cl.nome AS cliente, ca.modelo as carro
FROM cliente as cl
INNER JOIN aluguel AS al ON al.codcliente = cl.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
WHERE modelo = 'Onix'


''','carro_onix')
# Out:
#          cliente carro
# 0  Bruna Pereira  Onix

# %% [markdown]
# #22 - Liste os modelos de carros e o número de vezes que cada um foi alugado.

# %%
consulta('''
SELECT modelo, COUNT(al.codcarro) AS 'Qtd. alugado'
FROM carro as ca
JOIN aluguel AS al ON ca.codcarro = al.codcarro
GROUP BY modelo;
''','quantidade')
# Out:
#   modelo  Qtd. alugado
# 0     Ka             4
# 1   Argo             3
# 2   Onix             1
# 3   Polo             2

# %% [markdown]
# #23 - Liste o nome dos clientes e o número de aluguéis que cada um fez.

# %%
consulta('''
SELECT ca.nome, COUNT(al.codcliente) AS 'Qtd. alugado'
FROM cliente as ca
LEFT JOIN aluguel AS al ON ca.codcliente = al.codcliente
GROUP BY nome;
''','quantidade')
# Out:
#                nome  Qtd. alugado
# 0         Ana Silva             3
# 1     Bruna Pereira             3
# 2  Túlio Nascimento             2
# 3    Fernando Souza             0
# 4     Lúcia Andrade             2

# %% [markdown]
# #24 - Crie uma consulta que retorne o nome dos clientes e uma coluna adicional chamada status_civil que classifica os clientes como "Solteiro" ou "Casado".

# %%
consulta('''SELECT
ca.nome,
CASE
    WHEN ca.estadocivil = 'S' THEN 'Solteiro'
    WHEN ca.estadocivil = 'C' THEN 'Casado'
    ELSE 'Desconhecido'
END AS status_civil
FROM cliente AS ca;''','cliente_status')
# Out:
#                nome status_civil
# 0         Ana Silva       Casado
# 1     Bruna Pereira       Casado
# 2  Túlio Nascimento     Solteiro
# 3    Fernando Souza     Solteiro
# 4     Lúcia Andrade       Casado

# %% [markdown]
# # 25 - Liste os nomes dos clientes e as datas em que alugaram carros.

# %%
consulta('''
SELECT cl.nome, al.data_aluguel
FROM cliente as cl
INNER JOIN aluguel AS al ON al.codcliente = cl.codcliente
''','datas_alugadas')
# Out:
#                nome data_aluguel
# 0         Ana Silva   2023-04-05
# 1         Ana Silva   2023-04-13
# 2         Ana Silva   2023-04-15
# 3     Bruna Pereira   2023-04-02
# 4     Bruna Pereira   2023-04-03
# 5     Bruna Pereira   2023-04-04
# 6  Túlio Nascimento   2023-04-01
# 7  Túlio Nascimento   2023-04-25
# 8     Lúcia Andrade   2023-04-19
# 9     Lúcia Andrade   2023-04-21

# %% [markdown]
# # 26 - Liste todos os modelos de carros e suas respectivas marcas.

# %%
consulta('''
SELECT ca.modelo as modelo, ma.marca AS marca
FROM carro AS ca
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
''','datas_alugadas')
# Out:
#   modelo       marca
# 0     Ka        Ford
# 1   Argo        Fiat
# 2   Onix   Chevrolet
# 3   Polo  Volkswagen
# 4   Kwid     Renault

# %% [markdown]
# #27 - Liste todos os aluguéis e os nomes dos clientes que os realizaram.

# %%
consulta('''
SELECT cl.nome as cliente, al.codaluguel as 'ID do aluguel'
FROM aluguel AS al
INNER JOIN cliente as cl ON cl.codcliente = al.codcliente
''','nomes_alugueis')
# Out:
#             cliente  ID do aluguel
# 0         Ana Silva              5
# 1         Ana Silva              6
# 2         Ana Silva              7
# 3     Bruna Pereira              2
# 4     Bruna Pereira              3
# 5     Bruna Pereira              4
# 6  Túlio Nascimento              1
# 7  Túlio Nascimento             10
# 8     Lúcia Andrade              8
# 9     Lúcia Andrade              9

# %% [markdown]
# # 28 - Encontre o nome dos clientes e os modelos de carros que alugaram.

# %%
consulta('''
SELECT cl.nome as nome, al.codcarro as carro
FROM cliente as cl
INNER JOIN aluguel as al ON cl.codcliente
''','')
# Out:
#                 nome  carro
# 0      Lúcia Andrade      1
# 1     Fernando Souza      1
# 2   Túlio Nascimento      1
# 3      Bruna Pereira      1
# 4          Ana Silva      1
# 5      Lúcia Andrade      1
# 6     Fernando Souza      1
# 7   Túlio Nascimento      1
# 8      Bruna Pereira      1
# 9          Ana Silva      1
# 10     Lúcia Andrade      1
# 11    Fernando Souza      1
# 12  Túlio Nascimento      1
# 13     Bruna Pereira      1
# 14         Ana Silva      1
# 15     Lúcia Andrade      1
# 16    Fernando Souza      1
# 17  Túlio Nascimento      1
# 18     Bruna Pereira      1
# 19         Ana Silva      1
# 20     Lúcia Andrade      2
# 21    Fernando Souza      2
# 22  Túlio Nascimento      2
# 23     Bruna Pereira      2
# 24         Ana Silva      2
# 25     Lúcia Andrade      2
# 26    Fernando Souza      2
# 27  Túlio Nascimento      2
# 28     Bruna Pereira      2
# 29         Ana Silva      2
# 30     Lúcia Andrade      2
# 31    Fernando Souza      2
# ...

# %% [markdown]
# # 29 - Liste todos os carros e, se houver, mostre as datas em que foram alugados.

# %%
consulta('''
SELECT ca.modelo, al.data_aluguel
FROM carro AS ca
LEFT JOIN aluguel AS al ON ca.codcarro = al.codcarro;
''','carros_alugados')
# Out:
#    modelo data_aluguel
# 0      Ka   2023-04-02
# 1      Ka   2023-04-03
# 2      Ka   2023-04-15
# 3      Ka   2023-04-25
# 4    Argo   2023-04-01
# 5    Argo   2023-04-19
# 6    Argo   2023-04-21
# 7    Onix   2023-04-04
# 8    Polo   2023-04-05
# 9    Polo   2023-04-13
# 10   Kwid         None

# %% [markdown]
# # 30 - Encontre os clientes que moram na mesma cidade e estado e que alugaram carros.

# %%
consulta('''
SELECT DISTINCT c1.nome AS cliente1, c2.nome AS cliente2, c1.cidade, c1.estado
FROM cliente AS c1
INNER JOIN cliente AS c2
    ON c1.cidade = c2.cidade
    AND c1.estado = c2.estado
    AND c1.codcliente != c2.codcliente
INNER JOIN aluguel AS a1
    ON a1.codcliente = c1.codcliente
INNER JOIN aluguel AS a2
    ON a2.codcliente = c2.codcliente;
''','carros_alugados')
# Out:
#            cliente1          cliente2           cidade estado
# 0  Túlio Nascimento         Ana Silva  Duque de Caxias     RJ
# 1         Ana Silva  Túlio Nascimento  Duque de Caxias     RJ

# %% [markdown]
# # 31 - Liste os nomes dos clientes e os carros que eles alugaram, incluindo os clientes que não alugaram nenhum carro.

# %%
consulta('''SELECT cl.nome AS cliente, ca.modelo AS carro
FROM cliente AS cl
LEFT JOIN aluguel AS al ON cl.codcliente = al.codcliente
LEFT JOIN carro AS ca ON al.codcarro = ca.codcarro;
''','carros_nao_alugados')
# Out:
#              cliente carro
# 0          Ana Silva  Polo
# 1          Ana Silva  Polo
# 2          Ana Silva    Ka
# 3      Bruna Pereira    Ka
# 4      Bruna Pereira    Ka
# 5      Bruna Pereira  Onix
# 6   Túlio Nascimento  Argo
# 7   Túlio Nascimento    Ka
# 8     Fernando Souza  None
# 9      Lúcia Andrade  Argo
# 10     Lúcia Andrade  Argo

# %% [markdown]
# # 32 - Liste todas as marcas e, se houver, os modelos de carros associados.

# %%
consulta('''

SELECT ma.marca AS marca, ca.modelo AS modelo
FROM marca AS ma
LEFT JOIN carro AS ca ON ma.codmarca = ca.codmarca;''','todas_marcas')
# Out:
#         marca modelo
# 0        Ford     Ka
# 1        Fiat   Argo
# 2   Chevrolet   Onix
# 3  Volkswagen   Polo
# 4     Renault   Kwid

# %% [markdown]
# # 33 - Encontre todos os aluguéis e o estado civil dos clientes que alugaram os carros.

# %%
consulta('''
SELECT al.codaluguel, cl.nome AS cliente, cl.estadocivil
FROM aluguel AS al
INNER JOIN cliente AS cl ON al.codcliente = cl.codcliente;''','estadocivil')
# Out:
#    codaluguel           cliente estadocivil
# 0           5         Ana Silva           C
# 1           6         Ana Silva           C
# 2           7         Ana Silva           C
# 3           2     Bruna Pereira           C
# 4           3     Bruna Pereira           C
# 5           4     Bruna Pereira           C
# 6           1  Túlio Nascimento           S
# 7          10  Túlio Nascimento           S
# 8           8     Lúcia Andrade           C
# 9           9     Lúcia Andrade           C

# %% [markdown]
# # 34 - Liste os clientes e as cidades em que moram para aqueles que alugaram carros.

# %% [markdown]
# # 35 - Liste os clientes que alugaram carros e os modelos de carros que eles alugaram, incluindo a marca do carro.

# %%
consulta('''
SELECT  cl.nome AS cliente, ca.modelo, ma.marca
FROM aluguel
JOIN cliente as cl ON aluguel.codcliente = cliente.codcliente
JOIN carro as ca ON aluguel.codcarro = carro.codcarro
JOIN marca as ma ON carro.codmarca = marca.codmarca
ORDER BY cl.nome;''','')
# Out:
#   File "<ipython-input-1-220b287fa6f5>", line 1
#     consulta('''
#              ^
# SyntaxError: incomplete input

# %% [markdown]
# # 36 - Encontre todos os aluguéis realizados em uma cidade específica e liste os nomes dos clientes e os modelos de carros alugados.

# %%
consulta('''
SELECT cl.nome AS cliente, ca.modelo AS carro
FROM aluguel AS al
INNER JOIN cliente AS cl ON al.codcliente = cl.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
WHERE cl.cidade = 'RJ';
''','todos_alugueis')
# Out:
# Empty DataFrame
# Columns: [cliente, carro]
# Index: []

# %% [markdown]
# # 37 - Liste os modelos de carros e a quantidade de vezes que foram alugados.

# %%
consulta('''SELECT ca.modelo AS modelo, COUNT(al.codaluguel) AS quantidade_alugueis
FROM carro AS ca
LEFT JOIN aluguel AS al ON ca.codcarro = al.codcarro
GROUP BY ca.modelo;''','vezes_alugados')
# Out:
#   modelo  quantidade_alugueis
# 0     Ka                    4
# 1   Argo                    3
# 2   Onix                    1
# 3   Polo                    2
# 4   Kwid                    0

# %% [markdown]
# # 38 - Encontre os clientes que alugaram mais de um carro.

# %%
consulta('''SELECT cl.nome AS cliente, COUNT(DISTINCT al.codcarro) AS quantidade_carros
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
GROUP BY cl.nome
HAVING COUNT(DISTINCT al.codcarro) > 1;''','>1')
# Out:
#             cliente  quantidade_carros
# 0         Ana Silva                  2
# 1     Bruna Pereira                  2
# 2  Túlio Nascimento                  2

# %% [markdown]
# # 39 - Liste os clientes, as datas de aluguel e o valor do carro alugado.

# %%
consulta('''
SELECT cl.nome AS cliente, al.data_aluguel AS data_aluguel, ca.valor AS valor_aluguel
FROM aluguel AS al
INNER JOIN cliente AS cl ON al.codcliente = cl.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro;
''','dataevalor')
# Out:
#             cliente data_aluguel  valor_aluguel
# 0  Túlio Nascimento   2023-04-01          150.0
# 1     Bruna Pereira   2023-04-02          100.0
# 2     Bruna Pereira   2023-04-03          100.0
# 3     Bruna Pereira   2023-04-04          170.0
# 4         Ana Silva   2023-04-05          150.0
# 5         Ana Silva   2023-04-13          150.0
# 6         Ana Silva   2023-04-15          100.0
# 7     Lúcia Andrade   2023-04-19          150.0
# 8     Lúcia Andrade   2023-04-21          150.0
# 9  Túlio Nascimento   2023-04-25          100.0

# %% [markdown]
# # 40 - Liste os modelos de carros que nunca foram alugados.

# %%
consulta('''SELECT ca.modelo AS modelo
FROM carro AS ca
LEFT JOIN aluguel AS al ON ca.codcarro = al.codcarro
WHERE al.codcarro IS NULL;''','')
# Out:
#   modelo
# 0   Kwid

# %% [markdown]
# ##41 - Encontre os clientes que alugaram carros e o total gasto em aluguéis.

# %%
consulta('''SELECT cl.nome AS cliente, SUM(ca.valor) AS total_gasto
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
GROUP BY cl.nome;''','')
# Out:
#             cliente  total_gasto
# 0  Túlio Nascimento        250.0
# 1     Bruna Pereira        370.0
# 2         Ana Silva        400.0
# 3     Lúcia Andrade        300.0

# %% [markdown]
# ##42 - Liste as marcas de carros e o número total de aluguéis por marca.

# %%
consulta('''

SELECT ma.marca AS marca, COUNT(al.codaluguel) AS total_alugueis
FROM carro AS ca
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
INNER JOIN aluguel AS al ON ca.codcarro = al.codcarro
GROUP BY ma.marca;''','')
# Out:
#         marca  total_alugueis
# 0        Ford               4
# 1        Fiat               3
# 2   Chevrolet               1
# 3  Volkswagen               2

# %% [markdown]
# ## 43 - Encontre os clientes que alugaram carros em um determinado mês e ano, listando os modelos de carros e as datas de aluguel.

# %%
consulta('''
SELECT DISTINCT cl.nome, car.modelo, data_aluguel
FROM cliente AS cl
JOIN aluguel AS al ON cl.codcliente = al.codcliente
JOIN carro AS car ON al.codcarro = car.codcarro
WHERE MONTH(al.data_aluguel) = 04 AND YEAR(al.data_aluguel) = 2023;
''','clientes_modelos_aluguel_abril2023')
# Out:
#                nome modelo data_aluguel
# 0  Túlio Nascimento   Argo   2023-04-01
# 1     Bruna Pereira     Ka   2023-04-02
# 2     Bruna Pereira     Ka   2023-04-03
# 3     Bruna Pereira   Onix   2023-04-04
# 4         Ana Silva   Polo   2023-04-05
# 5         Ana Silva   Polo   2023-04-13
# 6         Ana Silva     Ka   2023-04-15
# 7     Lúcia Andrade   Argo   2023-04-19
# 8     Lúcia Andrade   Argo   2023-04-21
# 9  Túlio Nascimento     Ka   2023-04-25

# %% [markdown]
# ##44 - Liste os clientes que moram em estados diferentes e que alugaram carros, junto com os modelos alugados.

# %%
consulta('''
SELECT DISTINCT cl.nome AS cliente, ca.modelo AS modelo
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
WHERE MONTH(a.data_aluguel) = 4 AND YEAR(a.data_aluguel) = 2023
''','')
# Out:
# Empty DataFrame
# Columns: [cliente, modelo]
# Index: []

# %% [markdown]
# ##45 - Encontre os clientes que alugaram carros, os modelos de carros alugados, as marcas desses carros e as datas de aluguel, ordenando pelos nomes dos clientes.

# %%
consulta('''
SELECT cl.nome AS cliente, ca.modelo AS modelo, ma.marca AS marca, al.data_aluguel AS data_aluguel
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
ORDER BY cl.nome;''','')
# Out:
#             cliente modelo       marca data_aluguel
# 0         Ana Silva   Polo  Volkswagen   2023-04-05
# 1         Ana Silva   Polo  Volkswagen   2023-04-13
# 2         Ana Silva     Ka        Ford   2023-04-15
# 3     Bruna Pereira     Ka        Ford   2023-04-02
# 4     Bruna Pereira     Ka        Ford   2023-04-03
# 5     Bruna Pereira   Onix   Chevrolet   2023-04-04
# 6     Lúcia Andrade   Argo        Fiat   2023-04-19
# 7     Lúcia Andrade   Argo        Fiat   2023-04-21
# 8  Túlio Nascimento   Argo        Fiat   2023-04-01
# 9  Túlio Nascimento     Ka        Ford   2023-04-25

# %% [markdown]
# ##46 - Liste os clientes que alugaram carros mais de uma vez e os detalhes dos carros que alugaram.

# %%
consulta('''
SELECT cl.nome AS cliente, ca.modelo AS modelo, ma.marca AS marca, al.data_aluguel AS data_aluguel
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
WHERE cl.codcliente IN (
    SELECT codcliente
    FROM aluguel
    GROUP BY codcliente
    HAVING COUNT(*) > 1
)
ORDER BY cl.nome, al.data_aluguel;


''','')
# Out:
#             cliente modelo       marca data_aluguel
# 0         Ana Silva   Polo  Volkswagen   2023-04-05
# 1         Ana Silva   Polo  Volkswagen   2023-04-13
# 2         Ana Silva     Ka        Ford   2023-04-15
# 3     Bruna Pereira     Ka        Ford   2023-04-02
# 4     Bruna Pereira     Ka        Ford   2023-04-03
# 5     Bruna Pereira   Onix   Chevrolet   2023-04-04
# 6     Lúcia Andrade   Argo        Fiat   2023-04-19
# 7     Lúcia Andrade   Argo        Fiat   2023-04-21
# 8  Túlio Nascimento   Argo        Fiat   2023-04-01
# 9  Túlio Nascimento     Ka        Ford   2023-04-25

# %% [markdown]
# ##47 - Encontre os modelos de carros que foram alugados por clientes de cidades específicas e liste as marcas desses carros.

# %%
consulta('''
SELECT DISTINCT ca.modelo AS modelo, ma.marca AS marca, cl.cidade
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
WHERE cl.cidade = ('Duque de Caxias', 'Caxias');

''','')
# Out:
#   modelo       marca
# 0   Polo  Volkswagen
# 1     Ka        Ford
# 2   Argo        Fiat

# %% [markdown]
# ##48 - Liste os clientes que alugaram carros, os modelos e as marcas dos carros, e o total gasto em aluguéis, agrupado por cliente.

# %%
consulta('''
SELECT cl.nome AS cliente, ca.modelo AS modelo, ma.marca AS marca, SUM(ca.valor) AS total_gasto
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
GROUP BY cl.nome
ORDER BY cl.nome;

''','')
# Out:
#             cliente modelo       marca  total_gasto
# 0         Ana Silva     Ka        Ford        100.0
# 1         Ana Silva   Polo  Volkswagen        300.0
# 2     Bruna Pereira     Ka        Ford        200.0
# 3     Bruna Pereira   Onix   Chevrolet        170.0
# 4     Lúcia Andrade   Argo        Fiat        300.0
# 5  Túlio Nascimento   Argo        Fiat        150.0
# 6  Túlio Nascimento     Ka        Ford        100.0

# %% [markdown]
# ##49 - Encontre os carros que foram alugados nos últimos 30 dias e os clientes que os alugaram.

# %%
consulta('''
SELECT cl.nome AS nome, ca.modelo AS modelo, ma.marca AS marca, al.data_aluguel AS data_aluguel
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
WHERE al.data_aluguel >= CURRENT_DATE - INTERVAL 30 DAY
ORDER BY al.data_aluguel DESC;''','')
# Out:
# Empty DataFrame
# Columns: [nome, modelo, marca, data_aluguel]
# Index: []

# %% [markdown]
# ##50 - Liste os clientes, os carros que alugaram, as marcas desses carros, e o valor total gasto em aluguéis, filtrando por um intervalo de datas específico.

# %%
consulta('''
SELECT cl.nome AS cliente, ca.modelo AS modelo, ma.marca AS marca, SUM(ca.valor) AS total_gasto
FROM cliente AS cl
INNER JOIN aluguel AS al ON cl.codcliente = al.codcliente
INNER JOIN carro AS ca ON al.codcarro = ca.codcarro
INNER JOIN marca AS ma ON ca.codmarca = ma.codmarca
WHERE al.data_aluguel BETWEEN (SELECT MIN(data_aluguel) FROM aluguel) AND (SELECT MAX(data_aluguel) FROM aluguel)
GROUP BY cl.nome, ca.modelo, ma.marca
ORDER BY cl.nome;
''','')
# Out:
#             cliente modelo       marca  total_gasto
# 0         Ana Silva     Ka        Ford        100.0
# 1         Ana Silva   Polo  Volkswagen        300.0
# 2     Bruna Pereira     Ka        Ford        200.0
# 3     Bruna Pereira   Onix   Chevrolet        170.0
# 4     Lúcia Andrade   Argo        Fiat        300.0
# 5  Túlio Nascimento   Argo        Fiat        150.0
# 6  Túlio Nascimento     Ka        Ford        100.0
